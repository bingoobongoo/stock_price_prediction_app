# %%
import pandas as pd
import ta
import sqlalchemy

# %%
# %load_ext sql

# %%
engine = sqlalchemy.create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/stock_price")
# %sql postgresql://postgres:postgres@localhost:5432/stock_price

# %%
tickers = %sql SELECT ticker FROM company
tickers_df = tickers.DataFrame()
tickers_series = tickers_df['ticker']
tickers_series
# Out:
#  * postgresql://postgres:***@localhost:5432/stock_price
# 1684 rows affected.
# 0        AAL
# 1       AAOI
# 2       AAON
# 3       AAPL
# 4       ABCL
#         ...
# 1679      ZS
# 1680    ZUMZ
# 1681    ZURA
# 1682    ZVRA
# 1683    ZYME
# Name: ticker, Length: 1684, dtype: object

# %%
olhc_close_data = %sql SELECT s.company_id, c.ticker, s.date, s.close FROM company as c JOIN stock_price as s USING(company_id) WHERE c.ticker = 'AAL' ORDER BY s.date ASC
# Out:
#  * postgresql://postgres:***@localhost:5432/stock_price
# 4798 rows affected.

# %%
aal_close_df = olhc_close_data.DataFrame()
aal_close_df
# Out:
#       company_id ticker        date      close
# 0              1    AAL  2005-09-27  18.194906
# 1              1    AAL  2005-09-28  19.326197
# 2              1    AAL  2005-09-29  19.052805
# 3              1    AAL  2005-09-30  19.806995
# 4              1    AAL  2005-10-03  20.268936
# ...          ...    ...         ...        ...
# 4793           1    AAL  2024-10-14  11.870000
# 4794           1    AAL  2024-10-15  12.030000
# 4795           1    AAL  2024-10-16  12.890000
# 4796           1    AAL  2024-10-17  12.810000
# 4797           1    AAL  2024-10-18  13.090000
#
# [4798 rows x 4 columns]

# %%
rsi = ta.momentum.RSIIndicator(aal_close_df['close'])
rsi.rsi()
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 4793    62.549688
# 4794    64.821640
# 4795    73.964356
# 4796    72.087479
# 4797    74.524139
# Name: rsi, Length: 4798, dtype: float64

# %%
macd = ta.trend.MACD(aal_close_df['close'])
macd.macd().isna().sum()
# Out:
# np.int64(25)

# %%
for ticker in tickers_series[:3]:
    test = %sql SELECT s.company_id, c.ticker, s.date, s.close FROM company as c JOIN stock_price as s USING(company_id) WHERE c.ticker = '{ticker}' ORDER BY s.date ASC
    print(test)
# Out:
#  * postgresql://postgres:***@localhost:5432/stock_price
# 4798 rows affected.
# +------------+--------+------------+------------+
# | company_id | ticker |    date    |   close    |
# +------------+--------+------------+------------+
# |     1      |  AAL   | 2005-09-27 | 18.194906  |
# |     1      |  AAL   | 2005-09-28 | 19.326197  |
# |     1      |  AAL   | 2005-09-29 | 19.052805  |
# |     1      |  AAL   | 2005-09-30 | 19.806995  |
# |     1      |  AAL   | 2005-10-03 | 20.268936  |
# |     1      |  AAL   | 2005-10-04 | 20.891151  |
# |     1      |  AAL   | 2005-10-05 | 20.928862  |
# |     1      |  AAL   | 2005-10-06 |  21.2871   |
# |     1      |  AAL   | 2005-10-07 | 20.881721  |
# |     1      |  AAL   | 2005-10-10 | 20.938288  |
# |     1      |  AAL   | 2005-10-11 | 20.721457  |
# |     1      |  AAL   | 2005-10-12 | 20.514055  |
# |     1      |  AAL   | 2005-10-13 | 20.466915  |
# |     1      |  AAL   | 2005-10-14 | 20.994852  |
# ...
